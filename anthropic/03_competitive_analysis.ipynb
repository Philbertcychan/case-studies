# %% [markdown]
# # 03 - Competitive Analysis: Anthropic vs Competitors

# %% [markdown]
# This notebook benchmarks Anthropic against other leading AI foundation model companies across key dimensions:
#
# - Product Capabilities
# - Research Output
# - GTM Strategy
# - Pricing Models
# - Partnerships
# - Team and Leadership
#
# Our goal is to understand where Anthropic is differentiated, where it lags, and what this implies for strategy.

# %% [markdown]
# ## Competitor Set
#
# We will compare against:
#
# - **OpenAI**
# - **Google DeepMind**
# - **Mistral**
# - **Cohere**
# - **Meta**

# %% [markdown]
# ## Competitive Benchmark Table
#
# We'll build a dataframe from manually collected data for now. Later, this could be scraped or automated using APIs / web data.

# %%
import pandas as pd

data = [
    {
        "Company": "Anthropic",
        "Flagship Model": "Claude 3 Opus",
        "Pricing": "High (API; Opus ~$30/million tokens)",
        "Open-Source": "Partial (Claude 1 weights released)",
        "GTM Strategy": "API-first, Chatbot partners (e.g., Poe, Notion AI)",
        "Differentiator": "Constitutional AI, Safety focus",
        "Notable Partners": ["Amazon ($4B)", "Google Cloud", "Slack", "Notion"]
    },
    {
        "Company": "OpenAI",
        "Flagship Model": "GPT-4o",
        "Pricing": "Medium (GPT-4o ~$5/million tokens)",
        "Open-Source": "No",
        "GTM Strategy": "Direct API + ChatGPT",
        "Differentiator": "Fast iteration, multimodal integration",
        "Notable Partners": ["Microsoft", "Stripe", "Salesforce"]
    },
    {
        "Company": "Google DeepMind",
        "Flagship Model": "Gemini 1.5",
        "Pricing": "Unknown (via Google Cloud)",
        "Open-Source": "No",
        "GTM Strategy": "Vertical integration with Google products",
        "Differentiator": "Tight integration with Search & Workspace",
        "Notable Partners": ["Google Workspace", "Android"]
    },
    {
        "Company": "Cohere",
        "Flagship Model": "Command R+",
        "Pricing": "Low",
        "Open-Source": "Partial (R+ weights open)",
        "GTM Strategy": "Enterprise, retrieval-augmented focus",
        "Differentiator": "RAG-native, Canadian HQ",
        "Notable Partners": ["Oracle", "Nvidia Inference Platform"]
    },
    {
        "Company": "Meta",
        "Flagship Model": "LLaMA 3",
        "Pricing": "Free (open weights)",
        "Open-Source": "Yes",
        "GTM Strategy": "Community-driven, OSS-led",
        "Differentiator": "Scale + Open Weights",
        "Notable Partners": ["AWS", "HuggingFace"]
    },
    {
        "Company": "Mistral",
        "Flagship Model": "Mixtral 8x7B",
        "Pricing": "Free (open weights)",
        "Open-Source": "Yes",
        "GTM Strategy": "OSS-first, small efficient models",
        "Differentiator": "Sparse expert models, EU-based",
        "Notable Partners": ["Le Chat", "HuggingFace", "Nvidia"]
    },
]

df = pd.DataFrame(data)
df.set_index("Company", inplace=True)
df
# Out:
#                 Flagship Model                               Pricing  \
# Company
# Anthropic        Claude 3 Opus  High (API; Opus ~$30/million tokens)
# OpenAI                  GPT-4o    Medium (GPT-4o ~$5/million tokens)
# Google DeepMind     Gemini 1.5            Unknown (via Google Cloud)
# Cohere              Command R+                                   Low
# Meta                   LLaMA 3                   Free (open weights)
# Mistral           Mixtral 8x7B                   Free (open weights)
#
#                                          Open-Source  \
# Company
# Anthropic        Partial (Claude 1 weights released)
# OpenAI                                            No
# Google DeepMind                                   No
# Cohere                     Partial (R+ weights open)
# Meta                                             Yes
# Mistral                                          Yes
#
#                                                       GTM Strategy  \
# Company
# ...

# %% [markdown]
# ## Observations
#
# - Anthropic is priced higher than most (except maybe DeepMind if you include Google Cloud cost).
# - OpenAI has tighter end-user distribution (ChatGPT) vs. Anthropic’s partner-led GTM.
# - Meta and Mistral are going hard on open-source, which may influence developer adoption and mindshare.
# - Safety and reliability is Anthropic’s niche, but product breadth (multimodality, etc.) lags OpenAI and Google.
#
# What does this mean for Anthropic's positioning?
